# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_excel("bmw.xlsx")

# %%
dataFrame.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
dataFrame.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.distplot(dataFrame["price"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize=(20,20))
sbn.countplot(dataFrame["year"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
dataFrame.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.623756 -0.774382  0.025200 -0.071762   -0.026337
# price       0.623756  1.000000 -0.605397  0.263484 -0.204882    0.460196
# mileage    -0.774382 -0.605397  1.000000 -0.170747  0.118609   -0.002540
# tax         0.025200  0.263484 -0.170747  1.000000 -0.351798    0.429616
# mpg        -0.071762 -0.204882  0.118609 -0.351798  1.000000   -0.399844
# engineSize -0.026337  0.460196 -0.002540  0.429616 -0.399844    1.000000

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# mileage      -0.605397
# mpg          -0.204882
# tax           0.263484
# engineSize    0.460196
# year          0.623756
# price         1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x="mileage",y="price",data=dataFrame)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending = False).head(20)
# Out:
#           model  year   price transmission  mileage fuelType  tax   mpg  \
# 3638   2 Series  2015  123456    Semi-Auto    33419   Diesel   20  68.9
# 5362         M4  2016   99950    Automatic      771   Petrol  300  33.2
# 2909         M4  2017   89990    Semi-Auto     1336   Petrol  145  33.2
# 4776         M5  2019   89900    Semi-Auto     2269   Petrol  145  24.1
# 1813   8 Series  2019   88980    Semi-Auto       88   Petrol  145  24.4
# 721    8 Series  2019   84898    Semi-Auto     3185   Petrol  145  24.4
# 5877         M5  2019   81140    Semi-Auto      551   Petrol  145  24.1
# 6115   8 Series  2020   79991    Semi-Auto      151   Diesel  145  26.7
# 7024         X7  2020   79566    Semi-Auto     1000   Petrol  145  24.8
# 2602         X7  2020   78490    Semi-Auto     4919   Diesel  145  31.4
# 6446         X7  2019   78386    Automatic     1793   Diesel  145  31.4
# 241          X7  2020   78000    Semi-Auto     5000   Diesel  150  31.4
# ...

# %%
dataFrame.sort_values("price",ascending = True).head(20)
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 9744    3 Series  1999   1200    Automatic    82000   Petrol  245  31.0
# 9696    3 Series  2004   1445       Manual   162000   Diesel  205  49.6
# 9554    1 Series  2007   1500       Manual   167000   Diesel  125  57.6
# 10006   3 Series  2000   1550    Automatic    93000   Petrol  270  29.7
# 7284    5 Series  2002   1595    Automatic   115000   Petrol  325  28.5
# 9406    5 Series  2000   1699       Manual    99209   Petrol  265  29.4
# 9963          Z4  2004   1995       Manual   114000   Petrol  325  32.1
# 10009   3 Series  2002   2350       Manual    99000   Petrol  325  30.1
# 9220    3 Series  2007   2375       Manual    94000   Petrol  240  38.7
# 9918    1 Series  2010   2450       Manual   117454   Diesel   30  62.8
# 7358    1 Series  2004   2495       Manual   112000   Diesel  200  49.6
# 10714   3 Series  2005   2499       Manual   130000   Petrol  315  31.4
# ...

# %%
len(dataFrame)
# Out:
# 10781

# %%
len(dataFrame) * 0.01
# Out:
# 107.81

# %%
particularDF  = dataFrame.sort_values("price",ascending = False).iloc[107:]

# %%
particularDF.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10674.000000  10674.000000   10674.000000  10674.000000  10674.000000
# mean    2017.058741  22243.998969   25708.094716    131.552370     56.528921
# std        2.350808  10336.799736   25176.082905     61.751071     31.211385
# min     1996.000000   1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000  14880.000000    5651.250000    135.000000     46.300000
# 50%     2017.000000  20206.500000   18813.500000    145.000000     53.300000
# 75%     2019.000000  27500.000000   38492.750000    145.000000     62.800000
# max     2020.000000  64103.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10674.000000
# mean       2.157748
# std        0.540886
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
plt.figure(figsize=(7,5))
sbn.distplot(particularDF["price"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1996     5995.000000
# 1997     3950.000000
# 1998     3950.000000
# 1999     3285.000000
# 2000     1624.500000
# 2001     7333.333333
# 2002     5486.500000
# 2003     9222.500000
# 2004     8213.166667
# 2005     5390.166667
# 2006     5252.714286
# 2007     4830.500000
# 2008     6240.043478
# 2009     6618.100000
# 2010     7490.390244
# 2011     9099.098039
# 2012     9533.689076
# 2013    11118.355742
# 2014    13323.598802
# 2015    15199.753796
# 2016    16638.403826
# 2017    19267.174898
# 2018    22721.656840
# 2019    31025.864275
# 2020    35377.680764
# Name: price, dtype: float64

# %%
particularDF.groupby("year").mean()["price"]
# Out:
# year
# 1996     5995.000000
# 1997     3950.000000
# 1998     3950.000000
# 1999     3285.000000
# 2000     1624.500000
# 2001     7333.333333
# 2002     5486.500000
# 2003     9222.500000
# 2004     8213.166667
# 2005     5390.166667
# 2006     5252.714286
# 2007     4830.500000
# 2008     6240.043478
# 2009     6618.100000
# 2010     7490.390244
# 2011     9099.098039
# 2012     9533.689076
# 2013    11118.355742
# 2014    13323.598802
# 2015    15082.211726
# 2016    16561.987234
# 2017    19226.056977
# 2018    22620.611111
# 2019    30133.591256
# 2020    34170.064880
# Name: price, dtype: float64

# %%
dataFrame[dataFrame.year != 1996].groupby("year").mean()["price"]
# Out:
# year
# 1997     3950.000000
# 1998     3950.000000
# 1999     3285.000000
# 2000     1624.500000
# 2001     7333.333333
# 2002     5486.500000
# 2003     9222.500000
# 2004     8213.166667
# 2005     5390.166667
# 2006     5252.714286
# 2007     4830.500000
# 2008     6240.043478
# 2009     6618.100000
# 2010     7490.390244
# 2011     9099.098039
# 2012     9533.689076
# 2013    11118.355742
# 2014    13323.598802
# 2015    15199.753796
# 2016    16638.403826
# 2017    19267.174898
# 2018    22721.656840
# 2019    31025.864275
# 2020    35377.680764
# Name: price, dtype: float64

# %%
dataFrame = particularDF

# %%
dataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10674.000000  10674.000000   10674.000000  10674.000000  10674.000000
# mean    2017.058741  22243.998969   25708.094716    131.552370     56.528921
# std        2.350808  10336.799736   25176.082905     61.751071     31.211385
# min     1996.000000   1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000  14880.000000    5651.250000    135.000000     46.300000
# 50%     2017.000000  20206.500000   18813.500000    145.000000     53.300000
# 75%     2019.000000  27500.000000   38492.750000    145.000000     62.800000
# max     2020.000000  64103.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10674.000000
# mean       2.157748
# std        0.540886
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
dataFrame = dataFrame[dataFrame.year != 1998]

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1996     5995.000000
# 1997     3950.000000
# 1999     3285.000000
# 2000     1624.500000
# 2001     7333.333333
# 2002     5486.500000
# 2003     9222.500000
# 2004     8213.166667
# 2005     5390.166667
# 2006     5252.714286
# 2007     4830.500000
# 2008     6240.043478
# 2009     6618.100000
# 2010     7490.390244
# 2011     9099.098039
# 2012     9533.689076
# 2013    11118.355742
# 2014    13323.598802
# 2015    15082.211726
# 2016    16561.987234
# 2017    19226.056977
# 2018    22620.611111
# 2019    30133.591256
# 2020    34170.064880
# Name: price, dtype: float64

# %%
dataFrame.head()
# Out:
#           model  year  price transmission  mileage fuelType  tax    mpg  \
# 4805   8 Series  2019  64103    Semi-Auto     1897   Diesel  145   39.8
# 6177         X6  2019  63999    Semi-Auto     4000   Petrol  145   26.4
# 5140         X5  2020  63995    Automatic     5000   Hybrid  135  188.3
# 2566         X7  2020  63990    Semi-Auto     6137   Diesel  145   33.6
# 2891   8 Series  2018  63980    Semi-Auto     3891   Petrol  145   26.9
#
#       engineSize
# 4805         3.0
# 6177         3.0
# 5140         3.0
# 2566         3.0
# 2891         4.4

# %%
dataFrame = dataFrame.drop("transmission",axis=1)
dataFrame = dataFrame.drop("model",axis=1)
dataFrame = dataFrame.drop("fuelType",axis=1)

# %%
y = dataFrame["price"].values
x = dataFrame.drop("price",axis=1).values

# %%
y
# Out:
# array([64103, 63999, 63995, ...,  1500,  1445,  1200], dtype=int64)

# %%
x
# Out:
# array([[2.019e+03, 1.897e+03, 1.450e+02, 3.980e+01, 3.000e+00],
#        [2.019e+03, 4.000e+03, 1.450e+02, 2.640e+01, 3.000e+00],
#        [2.020e+03, 5.000e+03, 1.350e+02, 1.883e+02, 3.000e+00],
#        ...,
#        [2.007e+03, 1.670e+05, 1.250e+02, 5.760e+01, 2.000e+00],
#        [2.004e+03, 1.620e+05, 2.050e+02, 4.960e+01, 2.000e+00],
#        [1.999e+03, 8.200e+04, 2.450e+02, 3.100e+01, 2.800e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(x_train)
# Out:
# 7471

# %%
len(x_test)
# Out:
# 3202

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (7471, 5)

# %%
model = Sequential()

model.add(Dense(12, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(12, activation="relu"))

model.add(Dense(1))

model.compile(optimizer = "adam", loss = "mse")

# %%
model.fit(x=x_train, y=y_train, validation_data=(x_test,y_test),batch_size=250,epochs=300)
# Out:
# Epoch 1/300
# 30/30 [==============================] - 1s 8ms/step - loss: 595660096.0000 - val_loss: 615749952.0000
# Epoch 2/300
# 30/30 [==============================] - 0s 3ms/step - loss: 595647744.0000 - val_loss: 615731072.0000
# Epoch 3/300
# 30/30 [==============================] - 0s 3ms/step - loss: 595620480.0000 - val_loss: 615688960.0000
# Epoch 4/300
# 30/30 [==============================] - 0s 3ms/step - loss: 595555392.0000 - val_loss: 615587328.0000
# Epoch 5/300
# 30/30 [==============================] - 0s 3ms/step - loss: 595393280.0000 - val_loss: 615327296.0000
# Epoch 6/300
# 30/30 [==============================] - 0s 3ms/step - loss: 594980096.0000 - val_loss: 614680128.0000
# Epoch 7/300
# 30/30 [==============================] - 0s 3ms/step - loss: 594017600.0000 - val_loss: 613245120.0000
# Epoch 8/300
# 30/30 [==============================] - 0s 3ms/step - loss: 591997376.0000 - val_loss: 610394112.0000
# Epoch 9/300
# ...

# %%
lostData = pd.DataFrame(model.history.history)

# %%
lostData
# Out:
#             loss     val_loss
# 0    595660096.0  615749952.0
# 1    595647744.0  615731072.0
# 2    595620480.0  615688960.0
# 3    595555392.0  615587328.0
# 4    595393280.0  615327296.0
# ..           ...          ...
# 295   21095752.0   21561616.0
# 296   21070374.0   21545554.0
# 297   21096904.0   21527870.0
# 298   21054400.0   21509408.0
# 299   21031438.0   21540766.0
#
# [300 rows x 2 columns]

# %%
lostData.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
guessSeries = model.predict(x_test)
# Out:
# 101/101 [==============================] - 0s 1ms/step

# %%
guessSeries
# Out:
# array([[19639.889],
#        [26489.633],
#        [23016.24 ],
#        ...,
#        [12914.897],
#        [30233.703],
#        [25793.244]], dtype=float32)

# %%
mean_absolute_error(y_test,guessSeries)
# Out:
# 3258.371045088187

# %%
dataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10673.000000  10673.000000   10673.000000  10673.000000  10673.000000
# mean    2017.060527  22245.713014   25705.209688    131.539398     56.530910
# std        2.343667  10335.766943   25175.497823     61.739418     31.212171
# min     1996.000000   1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000  14880.000000    5651.000000    135.000000     46.300000
# 50%     2017.000000  20216.000000   18807.000000    145.000000     53.300000
# 75%     2019.000000  27500.000000   38489.000000    145.000000     62.800000
# max     2020.000000  64103.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10673.000000
# mean       2.157772
# std        0.540905
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
plt.scatter(y_test,guessSeries)
plt.plot(y_test,y_test,"r+-")

# %%
dataFrame.iloc[2]
# Out:
# year           2020.0
# price         63995.0
# mileage        5000.0
# tax             135.0
# mpg             188.3
# engineSize        3.0
# Name: 5140, dtype: float64

# %%
newCarSeries = dataFrame.drop("price",axis=1).iloc[2]

# %%
newCarSeries = scaler.transform(newCarSeries.values.reshape(-1,5))

# %%
model.predict(newCarSeries)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# array([[32219.566]], dtype=float32)
